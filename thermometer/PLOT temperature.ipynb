# %%
import pandas as pd

# %%
import pandas.io

# %%
import sqlite3

# %%
db = sqlite3.connect("therm.db")

# %%
d = pandas.io.sql.read_sql("SELECT * FROM temp", db)

# %%
d.head()
# Out:
#    id            read_time  temperature
# 0   1  2016-03-28 19:43:24       78.800
# 1   2  2016-03-28 19:43:40       78.575
# 2   3  2016-03-28 19:48:50       76.325
# 3   4  2016-03-28 19:53:51       75.650
# 4   5  2016-03-28 19:54:28       75.650

# %%
d.plot(x='read_time', y='temperature')

# %%
d.temperature.plot()
